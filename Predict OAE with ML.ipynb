# %% [markdown]
# # Predicting the Occurrence of Oceanic Anoxic Events with Ensemble Machine-Learning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mno

# %%
df = pd.read_excel('geochemical_dataset.xlsx', usecols = ['d13C_org', 'TOC', 'Mo', 'U', 'V','OAE2'])

# %%
df.dtypes
# Out:
# d13C_org    float64
# TOC         float64
# Mo          float64
# U           float64
# V           float64
# OAE2          int64
# dtype: object

# %%
df.describe()
# Out:
#          d13C_org          TOC           Mo           U              V  \
# count  679.000000  1592.000000  1291.000000  560.000000    1276.000000
# mean   -25.058836    10.171059    48.595497   20.469313    6780.477564
# std      1.921713     7.211198    57.884019   33.898765   21158.207324
# min    -30.160000     0.000000    -2.610000   -0.300000       0.000000
# 25%    -26.610000     4.785000     6.843900    2.837589     148.250000
# 50%    -25.290000     8.975000    32.000000    6.327068     516.500000
# 75%    -23.629166    14.210000    73.164300   17.800000    1544.750000
# max    -21.040000    30.430000   636.000000  162.900000  133203.883500
#
#               OAE2
# count  1592.000000
# mean      0.503141
# std       0.500147
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
df.isna().sum().sort_values()
# Out:
# TOC            0
# OAE2           0
# Mo           301
# V            316
# d13C_org     913
# U           1032
# dtype: int64

# %%
mno.bar(df);

# %%
cor = df.corr()
sns.set(rc = {'figure.figsize' : (10,8)})
sns.heatmap(cor, cmap=sns.color_palette("light:b", as_cmap=True), annot = True);

# %%
sns.set(style="white")
sns.pairplot(df, hue = 'OAE2');

# %% [markdown]
# # Data Imputation Using Linear Regression

# %%
from sklearn.linear_model import LinearRegression
def predict_NaN(col_name):
    df1 = df.copy()
    test_data = df[df[col_name].isnull()]
    df1=df1[['TOC', col_name]]
    df1.dropna(inplace=True)
    x_train = df1.drop(col_name,axis=1)
    y_train = df1[col_name]
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    x_test = test_data[['TOC']]
    y_pred = lr.predict(x_test)
    col_name_predicted = pd.Series(y_pred)
    col_name_predicted.index = df[col_name][df[col_name].isna()].index
    col_name_predicted = df[col_name].fillna(col_name_predicted)
    col_name_filled = pd.DataFrame({col_name:np.round(df[col_name],2), 
                                    col_name+' filled':np.round(col_name_predicted , 2)})
    df_filled = pd.DataFrame(col_name_filled)
    return(df_filled)

# %%
df_U = predict_NaN('U')
df_U.dropna(axis = 1,inplace=True)
df_V = predict_NaN('V')
df_V.dropna(axis = 1,inplace=True)
df_Mo = predict_NaN('Mo')
df_Mo.dropna(axis = 1,inplace=True)
df_d13C_org = predict_NaN('d13C_org')
df_d13C_org.dropna(axis = 1,inplace=True)

# %%
df_imputed = [df_Mo, df_U, df_V, df_d13C_org, df[['TOC']], df[['OAE2']]]
df_imputed = [df.set_index(df_U.index) for df in df_imputed]
df_imputed = df_imputed[0].join(df_imputed[1:])

# %%
df_imputed.describe()
# Out:
#          Mo filled     U filled       V filled  d13C_org filled          TOC  \
# count  1592.000000  1592.000000    1592.000000      1592.000000  1592.000000
# mean     48.296652    24.793675    6412.666514       -24.927305    10.171059
# std      52.253317    23.229172   18968.447762         1.356776     7.211198
# min      -2.610000    -0.300000       0.000000       -30.160000     0.000000
# 25%      10.290000     8.207500     215.712500       -25.710000     4.785000
# 50%      40.900000    20.100000     852.500000       -24.955000     8.975000
# 75%      65.405000    31.947500    3884.465000       -24.077500    14.210000
# max     636.000000   162.900000  133203.880000       -21.040000    30.430000
#
#               OAE2
# count  1592.000000
# mean      0.503141
# std       0.500147
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
df_imputed.isna().sum().sort_values()
# Out:
# Mo filled          0
# U filled           0
# V filled           0
# d13C_org filled    0
# TOC                0
# OAE2               0
# dtype: int64

# %%
mno.bar(df_imputed);

# %%
cor = df_imputed.corr()
sns.set(rc = {'figure.figsize' : (10,8)})
sns.heatmap(cor, cmap=sns.color_palette("light:b", as_cmap=True), annot = True);

# %%
sns.set(style="white")
sns.pairplot(df_imputed, hue = 'OAE2');

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import xgboost
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Train Test Split

# %%
train, test = train_test_split(df_imputed, test_size=0.2, random_state=123)
x_train = train.drop(columns=["OAE2"])
y_train = train["OAE2"]
x_test = test.drop(columns=["OAE2"])
y_test = test["OAE2"]

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier(n_estimators=30, max_depth=15, random_state=42)
rf.fit(x_train, y_train)
rf.score(x_test, y_test)
# Out:
# 0.890282131661442

# %%
y_pred_rf = rf.predict(x_test)
cm_rf = confusion_matrix(y_test, y_pred_rf)
cm_rf
# Out:
# array([[142,  14],
#        [ 21, 142]], dtype=int64)

# %%
plt.figure(figsize = (7 ,5))
ax = sns.heatmap(cm_rf, annot=True, fmt='g', cmap = sns.color_palette("light:b", as_cmap=True))
ax.set_title('Confusion Matrix for Random Forest')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.xaxis.set_ticklabels(['non-OAE2', 'OAE2'])
ax.yaxis.set_ticklabels(['non-OAE2', 'OAE2'])
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
dt.score(x_test, y_test)
# Out:
# 0.8589341692789969

# %%
y_pred_dt = dt.predict(x_test)
cm_dt = confusion_matrix(y_test, y_pred_dt)
cm_dt
# Out:
# array([[135,  21],
#        [ 24, 139]], dtype=int64)

# %%
plt.figure(figsize = (7 ,5))
ax = sns.heatmap(cm_dt, annot=True, fmt='g', cmap = sns.color_palette("light:b", as_cmap=True))
ax.set_title('Confusion Matrix for Decision Tree')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.xaxis.set_ticklabels(['non-OAE2', 'OAE2'])
ax.yaxis.set_ticklabels(['non-OAE2', 'OAE2'])
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
lr.score(x_test, y_test)
# Out:
# 0.8025078369905956

# %%
y_pred_lr = lr.predict(x_test)
cm_lr = confusion_matrix(y_test, y_pred_lr)
cm_lr
# Out:
# array([[139,  17],
#        [ 46, 117]], dtype=int64)

# %%
plt.figure(figsize = (7 ,5))
ax = sns.heatmap(cm_lr, annot=True, fmt='g', cmap = sns.color_palette("light:b", as_cmap=True))
ax.set_title('Confusion Matrix for Logisitc Regression')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.xaxis.set_ticklabels(['non-OAE2', 'OAE2'])
ax.yaxis.set_ticklabels(['non-OAE2', 'OAE2'])
plt.show()

# %% [markdown]
# ## XGBoost

# %%
xg_cl=xgboost.XGBClassifier(objective='binary:logistic', n_estimators=10, seed=123)
xg_cl.fit(x_train, y_train)
xg_cl.score(x_test, y_test)
# Out:
# 0.8808777429467085

# %%
y_pred_xg = xg_cl.predict(x_test)
cm_xg = confusion_matrix(y_test, y_pred_xg)
cm_xg
# Out:
# array([[137,  19],
#        [ 19, 144]], dtype=int64)

# %%
plt.figure(figsize = (7 ,5))
ax = sns.heatmap(cm_xg, annot=True, fmt='g', cmap = sns.color_palette("light:b", as_cmap=True))
ax.set_title('Confusion Matrix for XGBoost')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.xaxis.set_ticklabels(['non-OAE2', 'OAE2'])
ax.yaxis.set_ticklabels(['non-OAE2', 'OAE2'])
plt.show()

# %% [markdown]
# ## Feature Importance

# %%
def feature_importance(model):
    importances = model.feature_importances_
    std = np.std([tree.feature_importances_ for tree in rf.estimators_],axis=0)
    indices = np.argsort(importances)[::-1]
    print("Feature ranking:")
    for f in range(x_train.shape[1]):
        print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
    plt.figure(1, figsize=(8, 5))
    plt.title("Feature importances")
    plt.bar(range(x_train.shape[1]), importances[indices],color="teal", yerr=std[indices], align="center")
    plt.xticks(range(x_train.shape[1]), x_train.columns[indices],rotation=90)
    plt.xlim([-1, x_train.shape[1]])
    plt.show()

# %%
feature_importance(rf) #Random Forest
# Out:
# Feature ranking:
# 1. feature 3 (0.264570)
# 2. feature 0 (0.256812)
# 3. feature 2 (0.166304)
# 4. feature 1 (0.160820)
# 5. feature 4 (0.151494)

# %%
feature_importance(dt) #Decision Tree
# Out:
# Feature ranking:
# 1. feature 3 (0.364044)
# 2. feature 0 (0.336474)
# 3. feature 2 (0.134653)
# 4. feature 1 (0.093271)
# 5. feature 4 (0.071557)

# %%
feature_importance(xg_cl) #XGBoost
# Out:
# Feature ranking:
# 1. feature 3 (0.346253)
# 2. feature 0 (0.328805)
# 3. feature 2 (0.113976)
# 4. feature 4 (0.113186)
# 5. feature 1 (0.097780)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
importances = pd.DataFrame(data={
    'Attribute': x_train.columns,
    'Importance': model.coef_[0]
})
importances = importances.sort_values(by='Importance', ascending=False)
plt.bar(x=importances['Attribute'], height=importances['Importance'], color="teal")
plt.title('Feature importances', size=12)
plt.xticks(rotation='vertical')
plt.show();

# %% [markdown]
# # Blind Test

# %%
df_loc = pd.read_excel('geochemical_dataset.xlsx', usecols = ['location'])
df_with_loc = df_imputed.join(df_loc, on = df_imputed.index)
df_with_loc.head()
# Out:
#    Mo filled  U filled  V filled  d13C_org filled   TOC  OAE2     location
# 0      34.05      4.30   2452.15           -29.47  0.76     0  La Luna Sea
# 1      33.92      4.10   2414.27           -27.19  0.67     0  La Luna Sea
# 2      41.41     14.88   4497.41           -29.34  5.62     0  La Luna Sea
# 3      42.07     15.84   4682.58           -29.45  6.06     0  La Luna Sea
# 4      44.44     19.24   5339.09           -30.16  7.62     0  La Luna Sea

# %%
location = 'ODP'
TEST = df_with_loc[df_with_loc['location'] == location]
TEST.drop(columns=['location'], inplace=True)
TRAIN = df_with_loc[df_with_loc['location'] != location]
TRAIN.drop(columns=['location'], inplace=True)
# Out:
# C:\Users\G202112990\AppData\Local\Temp\ipykernel_2104\4244401138.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TEST.drop(columns=['location'], inplace=True)
# C:\Users\G202112990\AppData\Local\Temp\ipykernel_2104\4244401138.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TRAIN.drop(columns=['location'], inplace=True)

# %%
x_train = TRAIN.drop(columns=["OAE2"])
y_train = TRAIN["OAE2"]
x_test = TEST.drop(columns=["OAE2"])
y_test = TEST["OAE2"]

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier(n_estimators=30, max_depth=15, random_state=42)
rf.fit(x_train, y_train)
rf.score(x_test, y_test)
# Out:
# 0.7305555555555555

# %%
y_pred_rf = rf.predict(x_test)
cm_rf = confusion_matrix(y_test, y_pred_rf)
cm_rf
# Out:
# array([[354,  89],
#        [105, 172]], dtype=int64)

# %%
plt.figure(figsize = (7 ,5))
ax = sns.heatmap(cm_rf, annot=True, fmt='g', cmap = sns.color_palette("light:b", as_cmap=True))
ax.set_title('Confusion Matrix for Random Forest')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.xaxis.set_ticklabels(['non-OAE2', 'OAE2'])
ax.yaxis.set_ticklabels(['non-OAE2', 'OAE2'])
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
dt.score(x_test, y_test)
# Out:
# 0.7555555555555555

# %%
y_pred_dt = dt.predict(x_test)
cm_dt = confusion_matrix(y_test, y_pred_dt)
cm_dt
# Out:
# array([[364,  79],
#        [ 97, 180]], dtype=int64)

# %%
plt.figure(figsize = (7 ,5))
ax = sns.heatmap(cm_dt, annot=True, fmt='g', cmap = sns.color_palette("light:b", as_cmap=True))
ax.set_title('Confusion Matrix for Decision Tree')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.xaxis.set_ticklabels(['non-OAE2', 'OAE2'])
ax.yaxis.set_ticklabels(['non-OAE2', 'OAE2'])
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
lr.score(x_test, y_test)
# Out:
# C:\Users\G202112990\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8736111111111111

# %%
y_pred_lr = lr.predict(x_test)
cm_lr = confusion_matrix(y_test, y_pred_lr)
cm_lr
# Out:
# array([[439,   4],
#        [ 87, 190]], dtype=int64)

# %%
plt.figure(figsize = (7 ,5))
ax = sns.heatmap(cm_lr, annot=True, fmt='g', cmap = sns.color_palette("light:b", as_cmap=True))
ax.set_title('Confusion Matrix for Logisitc Regression')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.xaxis.set_ticklabels(['non-OAE2', 'OAE2'])
ax.yaxis.set_ticklabels(['non-OAE2', 'OAE2'])
plt.show()

# %% [markdown]
# ## XGBoost

# %%
xg_cl=xgboost.XGBClassifier(objective='binary:logistic', n_estimators=10, seed=123)
xg_cl.fit(x_train, y_train)
xg_cl.score(x_test, y_test)
# Out:
# 0.7277777777777777

# %%
y_pred_xg = xg_cl.predict(x_test)
cm_xg = confusion_matrix(y_test, y_pred_xg)
cm_xg
# Out:
# array([[359,  84],
#        [112, 165]], dtype=int64)

# %%
plt.figure(figsize = (7 ,5))
ax = sns.heatmap(cm_xg, annot=True, fmt='g', cmap = sns.color_palette("light:b", as_cmap=True))
ax.set_title('Confusion Matrix for XGBoost')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.xaxis.set_ticklabels(['non-OAE2', 'OAE2'])
ax.yaxis.set_ticklabels(['non-OAE2', 'OAE2'])
plt.show()

# %% [markdown]
# ## Feature Importance

# %%
def feature_importance(model):
    importances = model.feature_importances_
    std = np.std([tree.feature_importances_ for tree in rf.estimators_],axis=0)
    indices = np.argsort(importances)[::-1]
    print("Feature ranking:")
    for f in range(x_train.shape[1]):
        print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
    plt.figure(1, figsize=(8, 5))
    plt.title("Feature importances")
    plt.bar(range(x_train.shape[1]), importances[indices],color="teal", yerr=std[indices], align="center")
    plt.xticks(range(x_train.shape[1]), x_train.columns[indices],rotation=90)
    plt.xlim([-1, x_train.shape[1]])
    plt.show()

# %%
feature_importance(rf) #Random Forest
# Out:
# Feature ranking:
# 1. feature 3 (0.326202)
# 2. feature 0 (0.247945)
# 3. feature 2 (0.188805)
# 4. feature 4 (0.120711)
# 5. feature 1 (0.116337)

# %%
feature_importance(dt) #Decision Tree
# Out:
# Feature ranking:
# 1. feature 3 (0.400771)
# 2. feature 0 (0.262697)
# 3. feature 2 (0.174326)
# 4. feature 4 (0.104534)
# 5. feature 1 (0.057672)

# %%
feature_importance(xg_cl) #XGBoost
# Out:
# Feature ranking:
# 1. feature 3 (0.403544)
# 2. feature 0 (0.258075)
# 3. feature 2 (0.146221)
# 4. feature 4 (0.099920)
# 5. feature 1 (0.092239)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
importances = pd.DataFrame(data={
    'Attribute': x_train.columns,
    'Importance': model.coef_[0]
})
importances = importances.sort_values(by='Importance', ascending=False)
plt.bar(x=importances['Attribute'], height=importances['Importance'], color="teal")
plt.title('Feature importances', size=12)
plt.xticks(rotation='vertical')
plt.show();
# Out:
# C:\Users\G202112990\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## Blind Test Prediction Visualization

# %%
sns.set(style="white")
fig, axes = plt.subplots(figsize=(10,15))
ax1 = plt.subplot2grid((1,5), (0,0), rowspan = 1, colspan = 1)
ax2 = plt.subplot2grid((1,5), (0,1), rowspan = 1, colspan = 1)
ax3 = plt.subplot2grid((1,5), (0,2), rowspan = 1, colspan = 1)
ax4 = plt.subplot2grid((1,5), (0,3), rowspan = 1, colspan = 1)
ax5 = plt.subplot2grid((1,5), (0,4), rowspan = 1, colspan = 1)
ax1.imshow(pd.DataFrame(y_test), interpolation='none', aspect='auto',
                    cmap=sns.color_palette("light:b", as_cmap=True))
ax1.set_xlabel('True', fontsize=12,rotation=90)
ax1.set_yticklabels([])
ax1.set_xticklabels([])
ax2.imshow(pd.DataFrame(y_pred_rf), interpolation='none', aspect='auto',
                    cmap=sns.color_palette("light:b", as_cmap=True))
ax2.set_xlabel('Predicted (Random Forest)', fontsize=12,rotation=90)
ax2.set_yticklabels([])
ax2.set_xticklabels([])
ax3.imshow(pd.DataFrame(y_pred_dt), interpolation='none', aspect='auto',
                    cmap=sns.color_palette("light:b", as_cmap=True))
ax3.set_xlabel('Predicted (Decision Tree)', fontsize=12,rotation=90)
ax3.set_yticklabels([])
ax3.set_xticklabels([])
ax4.imshow(pd.DataFrame(y_pred_lr), interpolation='none', aspect='auto',
                    cmap=sns.color_palette("light:b", as_cmap=True))
ax4.set_xlabel('Predicted (Logistic Regression)', fontsize=12,rotation=90)
ax4.set_yticklabels([])
ax4.set_xticklabels([])
ax5.imshow(pd.DataFrame(y_pred_xg), interpolation='none', aspect='auto',
                    cmap=sns.color_palette("light:b", as_cmap=True))
ax5.set_xlabel('Predicted (XGBoost)', fontsize=12,rotation=90)
ax5.set_yticklabels([])
ax5.set_xticklabels([])
fig.subplots_adjust(wspace=0.1)
